# %% [markdown]
# # Importar un fichero para pasarlo a un modelo

# %%
# Importaciones
import pandas as pd

# %%
nombre_fichero = "../importaciones/modelo_de_ingreso.csv"
nombre_modelo = "modelo_de_ingreso"
# abrir el archivo nombre_fichero y convertirlo en un panda dataset
df = pd.read_csv(nombre_fichero, sep=';', encoding='utf-8', on_bad_lines="warn")

# mostrar df
df
# Out:
#    id_alumno  Edad     Género Plataforma Preferida Nota media de acceso  \
# 0          1    18  Masculino                MacOS                    9
# 1          2    18  Masculino                MacOS                    9
# 2          3    20   Femenino              Windows                  7,9
# 3          4    20   Femenino              Windows                  7,9
# 4          5    19       Otro                Linux                   10
# 5          6    19       Otro                Linux                   10
# 6          7    22   Femenino                MacOS                    6
# 7          8    22   Femenino                MacOS                    6
#
#   Asiste a clase
# 0          Nunca
# 1          Nunca
# 2   Regularmente
# 3   Regularmente
# 4        Siempre
# 5        Siempre
# 6          Nunca
# 7          Nunca

# %%
abrir la base de datos de sqlite3   
import sqlite3
conn = sqlite3.connect('../db.sqlite3')
c = conn.cursor()
